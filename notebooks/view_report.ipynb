# %%
# %load_ext autoreload
# %autoreload 2

# Move up a directory (until the root of the git repo),
# but only if this has not been done before.
if 'in_correct_dir' not in locals():
    # type: ignore
    # %cd -q ..
in_correct_dir = True
# %pwd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# '/home/wout/pp/code'

# %%
import pandas as pd

# %%
# df = pd.read_csv("artifacts/results/mnist_default_k10_e5.csv")
# df = pd.read_csv("artifacts/results/mnist_default_k5_e10.csv")
# df = pd.read_csv("artifacts/results/cifar10_default_k5_e10.csv")
# df = pd.read_csv("artifacts/results/segment_default_k5_e20.csv")
# df = pd.read_csv("artifacts/results/segment_default_k5_r5_e20.csv")
df = pd.read_csv("artifacts/results/segment_default_k5_r1_weighted.csv")
# df = pd.read_csv("artifacts/results/segment_default_k5_r5_weighted.csv")

import assessors.report as rr

df = rr.wrap.as_classification_with_binary_reward(df)

# display(rr.AssessorReport(df))
# rr.AssessorResults(df)
rr.AssessorCalibration(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/pp/code/.env/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/pp/code/assessors/report/html_report/renderer.py in _repr_html_(self)
#      18             return self.render()
#      19         except Exception as e:
# ---> 20             return self.on_error(e)
#      21
#      22     def __str__(self) -> str:
#
# ~/pp/code/assessors/report/html_report/renderer.py in on_error(self, e)
#      25     def on_error(self, e: Exception) -> str:
#      26         # return GenericError(e).render()
# ---> 27         raise e
#      28
#      29     def save(self, path: Path) -> None:
#
# ~/pp/code/assessors/report/html_report/renderer.py in _repr_html_(self)
#      16     def _repr_html_(self) -> str:
#      17         try:
# ---> 18             return self.render()
#      19         except Exception as e:
#      20             return self.on_error(e)
#
# ~/pp/code/assessors/report/html_report/html_report.py in render(self)
#     208         )
#     209         fig: Figure = cal.figure_
# --> 210         fig.title.set_text("Assessor vs. System (confidence calibration)")
#     211
#     212         return f'''
#
# AttributeError: 'Figure' object has no attribute 'title'
