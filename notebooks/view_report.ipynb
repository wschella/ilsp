# %%
# %load_ext autoreload
# %autoreload 2

# Move up a directory (until the root of the git repo),
# but only if this has not been done before.
if 'in_correct_dir' not in locals():
    # type: ignore
    # %cd -q ..
in_correct_dir = True
# %pwd
# Out:
# '/home/wout/pp/code'

# %%
import pandas as pd

# %%
# df = pd.read_csv("artifacts/results/mnist_default_k10_e5.csv")
# df = pd.read_csv("artifacts/results/mnist_default_k5_e10.csv")
# df = pd.read_csv("artifacts/results/cifar10_default_k5_e10.csv")
# df = pd.read_csv("artifacts/results/segment_default_k5_e20.csv")
# df = pd.read_csv("artifacts/results/segment_default_k5_r5_e20.csv")
# df = pd.read_csv("artifacts/results/segment_default_k5_r1_weighted.csv")
# df = pd.read_csv("artifacts/results/segment_default_k5_r5_weighted.csv")
df = pd.read_csv("results.csv")

import assessors.report as rr

df = rr.wrap.as_classification_with_binary_reward(df)

display(rr.AssessorClassWiseAggregation(df))
display(rr.AssessorReport(df))
# display(rr.AssessorResults(df))
# Out:
#         <div>
#             <h3>Class Wise Aggregation</h3>
#             <p>We report the times the assessor accuracy vs system accuracy</p>
#             <p>The system accuracy is averaged over all the systems in the population</p>
#             <img src="data:image/png;base64,...">
#         </div>
#         <h1>Report</h1>
#
#         <div>
#             <h2>Dataframe Sanity Check</h2>
#             <p>
#                 <b>Number of rows:</b> 12000 <br>
#                 <b>Example syst_prediction:</b> <br>
#                 [[6.85436011e-04 4.30279329e-07 4.29404169e-01 1.06951900e-01
#   8.68269429e-02 3.56176525e-01 1.73463449e-02 2.57864082e-03
#   2.64249156e-05 3.17152649e-06]]
#             </p>
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>inst_index</th>
#       <th>inst_target</th>
#       <th>syst_features</th>
#       <th>syst_pred_loss</th>
#       <th>syst_pred_score</th>
#       <th>asss_prediction</th>
#       <th>asss_pred_loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>57600</td>
#       <td>1</td>
#       <td>[0, 0]</td>
#       <td>0.001435</td>
#       <td>1.0</td>
#       <td>0.673243</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>45600</td>
#       <td>5</td>
#       <td>[1, 0]</td>
#       <td>1.032329</td>
#       <td>0.0</td>
#       <td>0.465972</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>33600</td>
#       <td>3</td>
#       <td>[2, 0]</td>
#       <td>1.357156</td>
#       <td>0.0</td>
#       <td>0.709448</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>21600</td>
#       <td>4</td>
#       <td>[3, 0]</td>
#       <td>0.041594</td>
#       <td>1.0</td>
#       <td>0.716964</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9600</td>
#       <td>9</td>
#       <td>[4, 0]</td>
#       <td>0.349331</td>
#       <td>1.0</td>
#       <td>0.526634</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#
#
#         <div>
#             <h2>System Results</h2>
#             <p>Mispredictions: 3816/12000 (68.20% acc)</p>
#             <pre>              precision    recall  f1-score   support
#
#            0       0.72      0.69      0.71      1141
#            1       0.83      0.73      0.78      1221
#            2       0.65      0.49      0.56      1201
#            3       0.51      0.48      0.50      1217
#            4       0.61      0.67      0.64      1203
#            5       0.59      0.55      0.57      1167
#            6       0.72      0.78      0.75      1182
#            7       0.72      0.76      0.74      1233
#            8       0.75      0.82      0.78      1245
#            9       0.69      0.84      0.76      1190
#
#     accuracy                           0.68     12000
#    macro avg       0.68      0.68      0.68     12000
# weighted avg       0.68      0.68      0.68     12000
# </pre>
#         </div>
#
#
#         <div>
#             <h2>Assessor Results</h2>
#
#         <div>
#             <h3>Scalar Metrics</h3>
#             <p>Brier Score: 0.21439684779826154     vs    TODO</p>
#             <ul>
#
#             <li>
#                 Mispredictions (threshold 50%): 4097/12000 (65.86% acc)<br>
#             </li>
#
#             <li>
#                 Mispredictions (threshold 75%): 5673/12000 (52.73% acc)<br>
#             </li>
#
#             <li>
#                 Mispredictions (threshold 90%): 7178/12000 (40.18% acc)<br>
#             </li>
#
#             </ul>
#         </div>
#
#
#         <div>
#             <h3>Classification Report</h3>
#             <p><strong>Threshold 50%</strong></p>
#             <pre>              precision    recall  f1-score   support
#
#          0.0       0.45      0.31      0.36      3816
#          1.0       0.72      0.82      0.77      8184
#
#     accuracy                           0.66     12000
#    macro avg       0.58      0.56      0.56     12000
# weighted avg       0.63      0.66      0.64     12000
# </pre>
#             <img src="data:image/png;base64,...">
#         </div>
#
#
#         <div>
#             <h3>Assessor ROC Curve</h3>
#             <img src="data:image/png;base64,...">
#         </div>
#
#
#         <div>
#             <h3>Assessor Precision-Recall Curve</h3>
#             <pre><img src="data:image/png;base64,..."></pre>
#         </div>
#
#
#         <div>
#             <h3>Assessor (Confidence) Calibration</h3>
#             <img src="data:image/png;base64,...">
#             <img src="data:image/png;base64,...">
#             <div>
#
#         <div>
#             <p>
#                 <em>4</em> quantiles,
#                 <em>3000.0</em> per quantile,
#                 <em>12000</em> total
#             </p>
#             <p>
#                 median: 0.66,
#                 mean:   0.66,
#             </p>
#             <ul>
#                 <li>0.521</li>
# <li>0.663</li>
# <li>0.805</li>
# <li>1.0</li>
#             </ul>
#         </div>
#
#             </div>
#         </div>
#
#
#         <div>
#             <h3>Class Wise Aggregation</h3>
#             <p>We report the times the assessor accuracy vs system accuracy</p>
#             <p>The system accuracy is averaged over all the systems in the population</p>
#             <img src="data:image/png;base64,...">
#         </div>
#
#         </div>
