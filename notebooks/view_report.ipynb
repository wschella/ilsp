# %%
# %load_ext autoreload
# %autoreload 2

# Move up a directory (until the root of the git repo),
# but only if this has not been done before.
if 'in_correct_dir' not in locals():
    # type: ignore
    # %cd -q ..
in_correct_dir = True
# %pwd
# Out:
# '/home/wout/pp/code'

# %%
import pandas as pd
import importlib
from IPython.lib import deepreload as dreload

# %%
import assessors.report as rr
df = pd.read_csv("artifacts/results/segment_default_k5_wln20/results.csv")
# df = pd.read_csv("artifacts/results/cifar10_default_k5_unweight/results.csv")
# df = pd.read_csv("results.csv")

df = rr.wrap.as_classification_with_binary_reward(df)

# display(rr.AssessorPerClassAggregation(df))
# display(rr.AssessorReport(df))
# display(rr.AssessorROCCurve(df))
display(rr.AssessorResults(df))
# Out:
#         <div>
#             <h2>Assessor Results</h2>
#
#         <div>
#             <h3>Scalar Metrics</h3>
#             <ul>
#
#             <li>
#                 Mispredictions (threshold 50%): 34/462 (92.64% acc)<br>
#             </li>
#
#             <li>
#                 Mispredictions (threshold 75%): 64/462 (86.15% acc)<br>
#             </li>
#
#             <li>
#                 Mispredictions (threshold 90%): 100/462 (78.35% acc)<br>
#             </li>
#
#             </ul>
#
#         <div>
#             <h4>Brier Score</h4>
#             <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>system_id</th>
#       <th>assessor</th>
#       <th>system</th>
#       <th>baseline_no_refinement</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[0, 0]</td>
#       <td>0.059870</td>
#       <td>0.052844</td>
#       <td>0.096881</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[1, 0]</td>
#       <td>0.052843</td>
#       <td>0.037023</td>
#       <td>0.051394</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[2, 0]</td>
#       <td>0.061672</td>
#       <td>0.111729</td>
#       <td>0.088256</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[3, 0]</td>
#       <td>0.022737</td>
#       <td>0.022351</td>
#       <td>0.021043</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[4, 0]</td>
#       <td>0.077783</td>
#       <td>0.069488</td>
#       <td>0.104290</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>all</td>
#       <td>0.054961</td>
#       <td>0.058632</td>
#       <td>0.073673</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#
#         </div>
#
#
#         <div>
#             <h3>Classification Report</h3>
#             <p><strong>Threshold 50%</strong></p>
#             <pre>              precision    recall  f1-score   support
#
#          0.0       0.54      0.51      0.53        37
#          1.0       0.96      0.96      0.96       425
#
#     accuracy                           0.93       462
#    macro avg       0.75      0.74      0.74       462
# weighted avg       0.92      0.93      0.93       462
# </pre>
#             <img src="data:image/png;base64,...">
#         </div>
#
#
#         <div>
#             <h3>Assessor ROC Curve</h3>
#             <img src="data:image/png;base64,...">
#         </div>
#
#
#         <div>
#             <h3>Assessor Precision-Recall Curve</h3>
#             <pre><img src="data:image/png;base64,..."></pre>
#         </div>
#
#
#         <div>
#             <h3>Assessor (Confidence) Calibration</h3>
#             <img src="data:image/png;base64,...">
#             <img src="data:image/png;base64,...">
#             <div>
#
#         <div>
#             <p>
#                 <em>4</em> quantiles,
#                 <em>115.5</em> per quantile,
#                 <em>462</em> total
#             </p>
#             <p>
#                 median: 0.99,
#                 mean:   0.89,
#             </p>
#             <ul>
#                 <li>0.863</li>
# <li>0.989</li>
# <li>0.998</li>
# <li>1.0</li>
#             </ul>
#         </div>
#
#             </div>
#         </div>
#
#
#         <div>
#             <h3>Soft Per-Class Aggregation</h3>
#             <img src="data:image/png;base64,...">
#
#             <h3>Crisp Per-Class Aggregation</h3>
#             <img src="data:image/png;base64,...">
#             <p>We report the times per-class actual accuracy of the system (actually avg of the systems)
#             compared to
#                 the systems self predicted accuracy by considering confidence <0.5 as predicted failure
#                 the assessors predicted accuracy, by similarly considering confidence <0.5 as predicted failure
#             </p>
#             <p><strong>The system accuracy is actually averaged over all the systems in the population<strong></p>
#         </div>
#
#         </div>
